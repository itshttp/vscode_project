# %%
import pandas as pd
import numpy as np
import time

# %%
time.timezone
# Out:
# 28800

# %%
from datetime import datetime

# Get current date and time
current_datetime = datetime.now()
current_datetime
# Out:
# datetime.datetime(2024, 8, 24, 12, 52, 28, 357498)

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 10, 5]

# Create a line plot
plt.plot(x, y, marker='o')

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Simple Line Graph')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [10, 15, 7, 10, 5]

y = [1, 2, 3, 4, 5]

# Create a line plot
plt.plot(x, y, marker='o')

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Simple Line Graph')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
y = [11, 11, 11, 11, 20]

x = [1, 2, 3, 4, 5]

# Create a line plot
plt.plot(x, y, marker='o')

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Simple Line Graph')

# Display the plot
plt.show()

# %%
print(f"Instead of new branch , try staging at { datetime.now().date()}")
# Out:
# Instead of new branch , try staging at 2024-08-24
